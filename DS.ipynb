# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("C:\\Users\\XPENDER\\Downloads\\news_posts.csv")

# %%
data.describe() 
#gives an overview
# Out:
#                  id    num_points  num_comments
# count  2.010000e+04  20100.000000  20100.000000
# mean   1.131753e+07     50.296070     24.802289
# std    6.964399e+05    107.107687     56.107340
# min    1.017691e+07      1.000000      1.000000
# 25%    1.070176e+07      3.000000      1.000000
# 50%    1.128445e+07      9.000000      3.000000
# 75%    1.192607e+07     54.000000     21.000000
# max    1.257898e+07   2553.000000   1733.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20100 entries, 0 to 20099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20100 non-null  int64
#  1   title         20100 non-null  object
#  2   url           17660 non-null  object
#  3   num_points    20100 non-null  int64
#  4   num_comments  20100 non-null  int64
#  5   author        20100 non-null  object
#  6   created_at    20100 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
#because time is an object here we will change that to date, using PANDAS
data["created_at"]=pd.to_datetime(data["created_at"])

# %%
data.info()
#now, you will see that object has changed to datetime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20100 entries, 0 to 20099
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20100 non-null  int64
#  1   title         20100 non-null  object
#  2   url           17660 non-null  object
#  3   num_points    20100 non-null  int64
#  4   num_comments  20100 non-null  int64
#  5   author        20100 non-null  object
#  6   created_at    20100 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 1.1+ MB

# %%
pd.options.display.max_rows = None

# %%
data["title"]
# Out:
# 0                                Interactive Dynamic Video
# 1        How to Use Open Source and Shut the Fuck Up at...
# 2        Florida DJs May Face Felony for April Fools' W...
# 3             Technology ventures: From Idea to Enterprise
# 4        Note by Note: The Making of Steinway L1037 (2007)
# 5        Title II kills investment? Comcast and other I...
# 6                           Nuts and Bolts Business Advice
# 7              Ask HN: How to improve my personal website?
# 8        Shims, Jigs and Other Woodworking Concepts to ...
# 9                                   That self-appendectomy
# 10       Crate raises $4M seed round for its next-gen S...
# 11       Advertising Cannot Maintain the Internet. Here...
# 12                                          Coding Is Over
# 13       Show HN: Wio Link  ESP8266 Based Web of Things...
# 14                  Custom Deleters for C++ Smart Pointers
# 15              How often to update third party libraries?
# ...

# %%
#to uniform everything, let's lower case all text
data["title"].str.lower()
# Out:
# 0                                interactive dynamic video
# 1        how to use open source and shut the fuck up at...
# 2        florida djs may face felony for april fools' w...
# 3             technology ventures: from idea to enterprise
# 4        note by note: the making of steinway l1037 (2007)
# 5        title ii kills investment? comcast and other i...
# 6                           nuts and bolts business advice
# 7              ask hn: how to improve my personal website?
# 8        shims, jigs and other woodworking concepts to ...
# 9                                   that self-appendectomy
# 10       crate raises $4m seed round for its next-gen s...
# 11       advertising cannot maintain the internet. here...
# 12                                          coding is over
# 13       show hn: wio link  esp8266 based web of things...
# 14                  custom deleters for c++ smart pointers
# 15              how often to update third party libraries?
# ...

# %%
ask_bol= data["title"].str.lower().str.startswith("ask hn")

# %%
ask_data=data[ask_bol] 
#bool is not in ""

# %%
show_bol = data["title"].str.lower().str.startswith("show hn")

# %%
show_data = data[show_bol]

# %%
show_data
# Out:
#              id                                              title  \
# 13     10627194  Show HN: Wio Link  ESP8266 Based Web of Things...
# 39     10646440                Show HN: Something pointless I made
# 46     11590768  Show HN: Shanhu.io, a programming playground p...
# 84     12178806  Show HN: Webscope  Easy way for web developers...
# 97     10872799  Show HN: GeoScreenshot  Easily test Geo-IP bas...
# 114    11237259            Show HN: Run with Mark (Runkeeper only)
# 120    10603601  Show HN: Send an email from your shell to your...
# 125    11370446  Show HN: Underline.js is like underscore.js bu...
# 127    10284074  Show HN: Real-Time Stats for an iOS MMORPG Gam...
# 129    12255593  Show HN: Bild  A collection of image processin...
# 130    10205375  Show HN: Automated coach for programming inter...
# 133    11848050     Show HN: /frink, a Slack app for Simpsons gifs
# 149    11134013  Show HN: Vector Toy  Visualize and manipulate ...
# ...

# %%
ask_data["num_comments"].describe()
# Out:
# count    1744.000000
# mean       14.038417
# std        52.947394
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         9.000000
# max       947.000000
# Name: num_comments, dtype: float64

# %%
show_data["num_comments"].describe()
# Out:
# count    1162.000000
# mean       10.316695
# std        23.325865
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         7.000000
# max       306.000000
# Name: num_comments, dtype: float64

# %%
show_avg= show_data["num_comments"].mean()

# %%
ask_avg= ask_data["num_comments"].mean()

# %%
avg_com = pd.Series({"ask_avg": 14.038417431192661,"show_avg": 10.31669535283993})

# %%
x = avg_com.index
y = avg_com.values
plt.figure(figsize=(7,6))
plt.bar(x,y)
plt.title("ASK VS SHOW Average comment comparision")
plt.xlabel("category")
plt.ylabel("Avg_com")
plt.savefig("ASk vs Show")
